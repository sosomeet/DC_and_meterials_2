# %%
# ============================================================
# Data Visualization for Spillover Dataset
# - Calendar-like availability heatmap
# - Distribution plots
# - Time series plots
# Path: ./merged_spillover_data.csv
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

# ----------------------------
# 1) Load Data
# ----------------------------
DATA_PATH = "./merged_spillover_data.csv"
df = pd.read_csv(DATA_PATH)

df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values("Date").reset_index(drop=True)

print("Data shape:", df.shape)
print("Date range:", df["Date"].min(), "~", df["Date"].max())

# Numeric columns only
num_cols = df.select_dtypes(include=["float64", "int64"]).columns.tolist()

# ============================================================
# 2) Calendar-like Availability Plot
# ============================================================

# Create full daily range
full_range = pd.date_range(df["Date"].min(), df["Date"].max(), freq="D")
calendar_df = pd.DataFrame({"Date": full_range})
calendar_df["has_data"] = calendar_df["Date"].isin(df["Date"]).astype(int)

calendar_df["Year"] = calendar_df["Date"].dt.year
calendar_df["Month"] = calendar_df["Date"].dt.month
calendar_df["Day"] = calendar_df["Date"].dt.day

# Pivot for heatmap (Year x Day-of-Year)
calendar_df["DayOfYear"] = calendar_df["Date"].dt.dayofyear

pivot = calendar_df.pivot_table(
    index="Year",
    columns="DayOfYear",
    values="has_data",
    fill_value=0
)

plt.figure(figsize=(18, 6))
sns.heatmap(pivot, cmap="Greens", cbar=False)
plt.title("Data Availability Calendar (1=Data, 0=Missing)")
plt.xlabel("Day of Year")
plt.ylabel("Year")
plt.tight_layout()
plt.show()

# ============================================================
# 3) Distribution Plots
# ============================================================

n_cols = 2
n_rows = int(np.ceil(len(num_cols) / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 4 * n_rows))
axes = axes.flatten()

for i, col in enumerate(num_cols):
    sns.histplot(df[col].dropna(), kde=True, ax=axes[i])
    axes[i].set_title(f"Distribution of {col}")

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# ============================================================
# 4) Time Series Plot
# ============================================================

fig, axes = plt.subplots(len(num_cols), 1, figsize=(14, 3 * len(num_cols)))

if len(num_cols) == 1:
    axes = [axes]

for i, col in enumerate(num_cols):
    axes[i].plot(df["Date"], df[col])
    axes[i].set_title(f"Time Series - {col}")
    axes[i].set_xlabel("Date")
    axes[i].set_ylabel(col)

plt.tight_layout()
plt.show()
# Out:
# Data shape: (1326, 6)
# Date range: 2020-10-12 00:00:00 ~ 2026-01-12 00:00:00

# %%
import pandas as pd
import matplotlib.pyplot as plt
import calendar

# ----------------------------
# Load Data
# ----------------------------
df = pd.read_csv("./merged_spillover_data.csv")
df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values("Date")

start_date = df["Date"].min()
end_date = df["Date"].max()

full_range = pd.date_range(start_date, end_date, freq="D")
has_data = set(df["Date"])

years = sorted(pd.Series(full_range).dt.year.unique())

for year in years:
    fig, axes = plt.subplots(3, 4, figsize=(18, 10))
    axes = axes.flatten()

    for month in range(1, 13):
        ax = axes[month - 1]
        ax.set_title(calendar.month_name[month], fontsize=12)

        cal = calendar.monthcalendar(year, month)

        ax.set_xlim(0, 7)
        ax.set_ylim(0, 6)
        ax.invert_yaxis()

        # 축/테두리/격자 완전 제거
        ax.axis("off")

        for week_idx, week in enumerate(cal):
            for day_idx, day in enumerate(week):
                if day == 0:
                    continue

                date = pd.Timestamp(year=year, month=month, day=day)

                if date in has_data:
                    color = "black"  # 데이터 있음
                else:
                    color = "lightgray"  # 데이터 없음

                ax.text(
                    day_idx + 0.5,
                    week_idx + 0.5,
                    str(day),
                    ha="center",
                    va="center",
                    fontsize=11,
                    color=color
                )

    plt.suptitle(f"Data Availability Calendar - {year}", fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
import os
import re
import pandas as pd
import numpy as np

FILES = {
    "SOLVPN": "./SOLVPN_index.csv",
    "COPPER": "./copper_futures.csv",
    "DXY": "./dollar_index.csv",
    "UST10Y": "./us_10y_bond_yield.csv",
    "VIX": "./cboe_vix_index.csv"
}

PREFERRED_VALUE_COLS = ["adj close", "adjusted close", "close", "price", "last", "value", "index", "settle"]

def _find_date_col(cols):
    cands = [c for c in cols if re.search(r"(date|time|timestamp)", c, re.IGNORECASE)]
    return cands[0] if cands else cols[0]

def _to_numeric(s: pd.Series) -> pd.Series:
    if s.dtype == "O":
        s = (s.astype(str)
               .str.strip()
               .str.replace(",", "", regex=False)
               .str.replace("%", "", regex=False))
    return pd.to_numeric(s, errors="coerce")

def load_series(path, name):
    df = pd.read_csv(path)
    date_col = _find_date_col(df.columns.tolist())
    df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
    df = df.dropna(subset=[date_col]).sort_values(date_col)

    # 선호 컬럼명 우선
    lower_map = {c.lower(): c for c in df.columns}
    chosen = None
    for key in PREFERRED_VALUE_COLS:
        if key in lower_map and lower_map[key] != date_col:
            chosen = lower_map[key]; break
        for lc, orig in lower_map.items():
            if key in lc and orig != date_col:
                chosen = orig; break
        if chosen is not None:
            break

    # 없으면 numeric 변환 성공률로 선택
    if chosen is None:
        best_col, best_ratio = None, -1.0
        for c in [c for c in df.columns if c != date_col]:
            s_num = _to_numeric(df[c])
            ratio = s_num.notna().mean()
            if ratio > best_ratio:
                best_ratio = ratio
                best_col = c
        if best_col is None or best_ratio <= 0.05:
            raise ValueError(f"[{name}] numeric-like column not found. cols={df.columns.tolist()}")
        chosen = best_col

    out = pd.DataFrame({
        "Date": df[date_col],
        name: _to_numeric(df[chosen])
    }).dropna(subset=[name])

    out = out.sort_values("Date").drop_duplicates("Date", keep="last").reset_index(drop=True)
    print(f"[{name}] date_col='{date_col}', value_col='{chosen}', rows={len(out)}")
    return out

# 1) Load all
series_list = []
for name, path in FILES.items():
    if not os.path.exists(path):
        raise FileNotFoundError(f"Missing file: {path}  (현재 경로 ./ 에 두셨는지 확인)")
    series_list.append(load_series(path, name))

# 2) OUTER merge (원인 추적용)
outer = series_list[0]
for s in series_list[1:]:
    outer = outer.merge(s, on="Date", how="outer")

outer = outer.sort_values("Date").reset_index(drop=True)

# 3) 어떤 날짜에 어떤 컬럼이 빠졌는지: weekday(월~금)만
outer["weekday"] = outer["Date"].dt.weekday  # 0=Mon ... 6=Sun
cols = [c for c in outer.columns if c not in ["Date", "weekday"]]

# 최소 1개라도 결측이면 "결측 날짜"로 표시
missing_mask = outer[cols].isna().any(axis=1)
missing_weekday = outer[missing_mask & (outer["weekday"] < 5)].copy()

# 4) 원인 컬럼 리스트업
def missing_cols(row):
    return [c for c in cols if pd.isna(row[c])]

missing_weekday["missing_cols"] = missing_weekday.apply(missing_cols, axis=1)

print("\n=== Missing weekdays (Mon-Fri) with causes ===")
if len(missing_weekday) == 0:
    print("No missing weekday rows in OUTER-merged table.")
else:
    for _, r in missing_weekday.iterrows():
        d = r["Date"].date()
        causes = ", ".join(r["missing_cols"])
        print(f"{d} : {causes}")

# 원하면 CSV로 저장
missing_weekday[["Date", "missing_cols"]].to_csv("./missing_weekday_causes.csv", index=False)
print("\nSaved: ./missing_weekday_causes.csv")
# Out:
# [SOLVPN] date_col='Date', value_col='Close', rows=1344
# [COPPER] date_col='Date', value_col='Close', rows=2618
# [DXY] date_col='Date', value_col='Close', rows=2595
# [UST10Y] date_col='Date', value_col='Close', rows=2619
# [VIX] date_col='Date', value_col='Close', rows=1558
#
# === Missing weekdays (Mon-Fri) with causes ===
# 2016-01-04 : SOLVPN, VIX
# 2016-01-05 : SOLVPN, VIX
# 2016-01-06 : SOLVPN, VIX
# 2016-01-07 : SOLVPN, VIX
# 2016-01-08 : SOLVPN, VIX
# 2016-01-11 : SOLVPN, VIX
# 2016-01-12 : SOLVPN, VIX
# 2016-01-13 : SOLVPN, VIX
# 2016-01-14 : SOLVPN, VIX
# 2016-01-15 : SOLVPN, VIX
# 2016-01-18 : SOLVPN, COPPER, VIX
# 2016-01-19 : SOLVPN, VIX
# 2016-01-20 : SOLVPN, VIX
# 2016-01-21 : SOLVPN, VIX
# 2016-01-22 : SOLVPN, VIX
# 2016-01-25 : SOLVPN, VIX
# 2016-01-26 : SOLVPN, VIX
# 2016-01-27 : SOLVPN, VIX
# 2016-01-28 : SOLVPN, VIX
# 2016-01-29 : SOLVPN, VIX
# 2016-02-01 : SOLVPN, VIX
# 2016-02-02 : SOLVPN, VIX
# 2016-02-03 : SOLVPN, VIX
# 2016-02-04 : SOLVPN, VIX
# 2016-02-05 : SOLVPN, VIX
# 2016-02-08 : SOLVPN, VIX
# 2016-02-09 : SOLVPN, VIX
# 2016-02-10 : SOLVPN, VIX
# 2016-02-11 : SOLVPN, VIX
# 2016-02-12 : SOLVPN, VIX
# 2016-02-15 : SOLVPN, COPPER, VIX
# 2016-02-16 : SOLVPN, VIX
# 2016-02-17 : SOLVPN, VIX
# 2016-02-18 : SOLVPN, VIX
# 2016-02-19 : SOLVPN, VIX
# 2016-02-22 : SOLVPN, VIX
# 2016-02-23 : SOLVPN, VIX
# 2016-02-24 : SOLVPN, VIX
# 2016-02-25 : SOLVPN, VIX
# 2016-02-26 : SOLVPN, VIX
# 2016-02-29 : SOLVPN, VIX
# 2016-03-01 : SOLVPN, VIX
# 2016-03-02 : SOLVPN, VIX
# 2016-03-03 : SOLVPN, VIX
# 2016-03-04 : SOLVPN, VIX
# 2016-03-07 : SOLVPN, VIX
# 2016-03-08 : SOLVPN, VIX
# 2016-03-09 : SOLVPN, VIX
# 2016-03-10 : SOLVPN, VIX
# 2016-03-11 : SOLVPN, VIX
# 2016-03-14 : SOLVPN, VIX
# 2016-03-15 : SOLVPN, VIX
# 2016-03-16 : SOLVPN, VIX
# 2016-03-17 : SOLVPN, VIX
# 2016-03-18 : SOLVPN, VIX
# 2016-03-21 : SOLVPN, VIX
# 2016-03-22 : SOLVPN, VIX
# 2016-03-23 : SOLVPN, VIX
# 2016-03-24 : SOLVPN, VIX
# 2016-03-28 : SOLVPN, VIX
# 2016-03-29 : SOLVPN, VIX
# 2016-03-30 : SOLVPN, VIX
# 2016-03-31 : SOLVPN, VIX
# 2016-04-01 : SOLVPN, VIX
# 2016-04-04 : SOLVPN, VIX
# 2016-04-05 : SOLVPN, VIX
# 2016-04-06 : SOLVPN, VIX
# 2016-04-07 : SOLVPN, VIX
# 2016-04-08 : SOLVPN, VIX
# 2016-04-11 : SOLVPN, VIX
# 2016-04-12 : SOLVPN, VIX
# 2016-04-13 : SOLVPN, VIX
# 2016-04-14 : SOLVPN, VIX
# 2016-04-15 : SOLVPN, VIX
# 2016-04-18 : SOLVPN, VIX
# 2016-04-19 : SOLVPN, VIX
# 2016-04-20 : SOLVPN, VIX
# 2016-04-21 : SOLVPN, VIX
# 2016-04-22 : SOLVPN, VIX
# 2016-04-25 : SOLVPN, VIX
# 2016-04-26 : SOLVPN, VIX
# 2016-04-27 : SOLVPN, VIX
# 2016-04-28 : SOLVPN, VIX
# 2016-04-29 : SOLVPN, VIX
# 2016-05-02 : SOLVPN, VIX
# 2016-05-03 : SOLVPN, VIX
# 2016-05-04 : SOLVPN, VIX
# 2016-05-05 : SOLVPN, VIX
# 2016-05-06 : SOLVPN, VIX
# 2016-05-09 : SOLVPN, VIX
# 2016-05-10 : SOLVPN, VIX
# 2016-05-11 : SOLVPN, VIX
# 2016-05-12 : SOLVPN, VIX
# 2016-05-13 : SOLVPN, VIX
# 2016-05-16 : SOLVPN, VIX
# 2016-05-17 : SOLVPN, VIX
# 2016-05-18 : SOLVPN, VIX
# 2016-05-19 : SOLVPN, VIX
# 2016-05-20 : SOLVPN, VIX
# 2016-05-23 : SOLVPN, VIX
# 2016-05-24 : SOLVPN, VIX
# 2016-05-25 : SOLVPN, VIX
# 2016-05-26 : SOLVPN, VIX
# 2016-05-27 : SOLVPN, VIX
# 2016-05-30 : SOLVPN, COPPER, VIX
# 2016-05-31 : SOLVPN, VIX
# 2016-06-01 : SOLVPN, VIX
# 2016-06-02 : SOLVPN, VIX
# 2016-06-03 : SOLVPN, VIX
# 2016-06-06 : SOLVPN, VIX
# 2016-06-07 : SOLVPN, VIX
# 2016-06-08 : SOLVPN, VIX
# 2016-06-09 : SOLVPN, VIX
# 2016-06-10 : SOLVPN, VIX
# 2016-06-13 : SOLVPN, VIX
# 2016-06-14 : SOLVPN, VIX
# 2016-06-15 : SOLVPN, VIX
# 2016-06-16 : SOLVPN, VIX
# 2016-06-17 : SOLVPN, VIX
# 2016-06-20 : SOLVPN, VIX
# 2016-06-21 : SOLVPN, VIX
# 2016-06-22 : SOLVPN, VIX
# 2016-06-23 : SOLVPN, VIX
# 2016-06-24 : SOLVPN, VIX
# 2016-06-27 : SOLVPN, VIX
# 2016-06-28 : SOLVPN, VIX
# 2016-06-29 : SOLVPN, VIX
# 2016-06-30 : SOLVPN, VIX
# 2016-07-01 : SOLVPN, VIX
# 2016-07-04 : SOLVPN, COPPER, VIX
# 2016-07-05 : SOLVPN, VIX
# 2016-07-06 : SOLVPN, VIX
# 2016-07-07 : SOLVPN, VIX
# 2016-07-08 : SOLVPN, VIX
# 2016-07-11 : SOLVPN, VIX
# 2016-07-12 : SOLVPN, VIX
# 2016-07-13 : SOLVPN, VIX
# 2016-07-14 : SOLVPN, VIX
# 2016-07-15 : SOLVPN, VIX
# 2016-07-18 : SOLVPN, VIX
# 2016-07-19 : SOLVPN, VIX
# 2016-07-20 : SOLVPN, VIX
# 2016-07-21 : SOLVPN, VIX
# 2016-07-22 : SOLVPN, VIX
# 2016-07-25 : SOLVPN, VIX
# 2016-07-26 : SOLVPN, VIX
# 2016-07-27 : SOLVPN, VIX
# 2016-07-28 : SOLVPN, VIX
# 2016-07-29 : SOLVPN, VIX
# 2016-08-01 : SOLVPN, VIX
# 2016-08-02 : SOLVPN, VIX
# 2016-08-03 : SOLVPN, VIX
# 2016-08-04 : SOLVPN, VIX
# 2016-08-05 : SOLVPN, VIX
# 2016-08-08 : SOLVPN, VIX
# 2016-08-09 : SOLVPN, VIX
# 2016-08-10 : SOLVPN, VIX
# 2016-08-11 : SOLVPN, VIX
# 2016-08-12 : SOLVPN, VIX
# 2016-08-15 : SOLVPN, VIX
# 2016-08-16 : SOLVPN, VIX
# 2016-08-17 : SOLVPN, VIX
# 2016-08-18 : SOLVPN, VIX
# 2016-08-19 : SOLVPN, VIX
# 2016-08-22 : SOLVPN, VIX
# 2016-08-23 : SOLVPN, VIX
# 2016-08-24 : SOLVPN, VIX
# 2016-08-25 : SOLVPN, VIX
# 2016-08-26 : SOLVPN, VIX
# 2016-08-29 : SOLVPN, VIX
# 2016-08-30 : SOLVPN, VIX
# 2016-08-31 : SOLVPN, VIX
# 2016-09-01 : SOLVPN, VIX
# 2016-09-02 : SOLVPN, VIX
# 2016-09-05 : SOLVPN, COPPER, VIX
# 2016-09-06 : SOLVPN, VIX
# 2016-09-07 : SOLVPN, VIX
# 2016-09-08 : SOLVPN, VIX
# 2016-09-09 : SOLVPN, VIX
# 2016-09-12 : SOLVPN, VIX
# 2016-09-13 : SOLVPN, VIX
# 2016-09-14 : SOLVPN, VIX
# 2016-09-15 : SOLVPN, VIX
# 2016-09-16 : SOLVPN, VIX
# 2016-09-19 : SOLVPN, VIX
# 2016-09-20 : SOLVPN, VIX
# 2016-09-21 : SOLVPN, VIX
# 2016-09-22 : SOLVPN, VIX
# 2016-09-23 : SOLVPN, VIX
# 2016-09-26 : SOLVPN, VIX
# 2016-09-27 : SOLVPN, VIX
# 2016-09-28 : SOLVPN, VIX
# 2016-09-29 : SOLVPN, VIX
# 2016-09-30 : SOLVPN, VIX
# 2016-10-03 : SOLVPN, VIX
# 2016-10-04 : SOLVPN, VIX
# 2016-10-05 : SOLVPN, VIX
# 2016-10-06 : SOLVPN, VIX
# 2016-10-07 : SOLVPN, VIX
# 2016-10-10 : SOLVPN, VIX
# 2016-10-11 : SOLVPN, VIX
# 2016-10-12 : SOLVPN, VIX
# 2016-10-13 : SOLVPN, VIX
# 2016-10-14 : SOLVPN, VIX
# 2016-10-17 : SOLVPN, VIX
# 2016-10-18 : SOLVPN, VIX
# 2016-10-19 : SOLVPN, VIX
# 2016-10-20 : SOLVPN, VIX
# 2016-10-21 : SOLVPN, VIX
# 2016-10-24 : SOLVPN, VIX
# 2016-10-25 : SOLVPN, VIX
# 2016-10-26 : SOLVPN, VIX
# 2016-10-27 : SOLVPN, VIX
# 2016-10-28 : SOLVPN, VIX
# 2016-10-31 : SOLVPN, VIX
# 2016-11-01 : SOLVPN, VIX
# 2016-11-02 : SOLVPN, VIX
# 2016-11-03 : SOLVPN, VIX
# 2016-11-04 : SOLVPN, VIX
# 2016-11-07 : SOLVPN, VIX
# 2016-11-08 : SOLVPN, VIX
# 2016-11-09 : SOLVPN, VIX
# 2016-11-10 : SOLVPN, VIX
# 2016-11-11 : SOLVPN, UST10Y, VIX
# 2016-11-14 : SOLVPN, VIX
# 2016-11-15 : SOLVPN, VIX
# 2016-11-16 : SOLVPN, VIX
# 2016-11-17 : SOLVPN, VIX
# 2016-11-18 : SOLVPN, VIX
# 2016-11-21 : SOLVPN, VIX
# 2016-11-22 : SOLVPN, VIX
# 2016-11-23 : SOLVPN, VIX
# 2016-11-24 : SOLVPN, COPPER, VIX
# 2016-11-25 : SOLVPN, VIX
# 2016-11-28 : SOLVPN, VIX
# 2016-11-29 : SOLVPN, VIX
# 2016-11-30 : SOLVPN, VIX
# 2016-12-01 : SOLVPN, VIX
# 2016-12-02 : SOLVPN, VIX
# 2016-12-05 : SOLVPN, VIX
# 2016-12-06 : SOLVPN, VIX
# 2016-12-07 : SOLVPN, VIX
# 2016-12-08 : SOLVPN, VIX
# 2016-12-09 : SOLVPN, VIX
# 2016-12-12 : SOLVPN, VIX
# 2016-12-13 : SOLVPN, VIX
# 2016-12-14 : SOLVPN, VIX
# 2016-12-15 : SOLVPN, VIX
# 2016-12-16 : SOLVPN, VIX
# 2016-12-19 : SOLVPN, VIX
# 2016-12-20 : SOLVPN, VIX
# 2016-12-21 : SOLVPN, VIX
# 2016-12-22 : SOLVPN, VIX
# 2016-12-23 : SOLVPN, VIX
# 2016-12-26 : SOLVPN, COPPER, DXY, VIX
# 2016-12-27 : SOLVPN, VIX
# 2016-12-28 : SOLVPN, VIX
# 2016-12-29 : SOLVPN, VIX
# 2016-12-30 : SOLVPN, VIX
# 2017-01-02 : SOLVPN, COPPER, DXY, VIX
# 2017-01-03 : SOLVPN, VIX
# 2017-01-04 : SOLVPN, VIX
# 2017-01-05 : SOLVPN, VIX
# 2017-01-06 : SOLVPN, VIX
# 2017-01-09 : SOLVPN, VIX
# 2017-01-10 : SOLVPN, VIX
# 2017-01-11 : SOLVPN, VIX
# 2017-01-12 : SOLVPN, VIX
# 2017-01-13 : SOLVPN, VIX
# 2017-01-16 : SOLVPN, COPPER, VIX
# 2017-01-17 : SOLVPN, VIX
# 2017-01-18 : SOLVPN, VIX
# 2017-01-19 : SOLVPN, VIX
# 2017-01-20 : SOLVPN, VIX
# 2017-01-23 : SOLVPN, VIX
# 2017-01-24 : SOLVPN, VIX
# 2017-01-25 : SOLVPN, VIX
# 2017-01-26 : SOLVPN, VIX
# 2017-01-27 : SOLVPN, VIX
# 2017-01-30 : SOLVPN, VIX
# 2017-01-31 : SOLVPN, VIX
# 2017-02-01 : SOLVPN, VIX
# 2017-02-02 : SOLVPN, VIX
# 2017-02-03 : SOLVPN, VIX
# 2017-02-06 : SOLVPN, VIX
# 2017-02-07 : SOLVPN, VIX
# 2017-02-08 : SOLVPN, VIX
# 2017-02-09 : SOLVPN, VIX
# 2017-02-10 : SOLVPN, VIX
# 2017-02-13 : SOLVPN, VIX
# 2017-02-14 : SOLVPN, VIX
# 2017-02-15 : SOLVPN, VIX
# 2017-02-16 : SOLVPN, VIX
# 2017-02-17 : SOLVPN, VIX
# 2017-02-20 : SOLVPN, COPPER, VIX
# 2017-02-21 : SOLVPN, VIX
# 2017-02-22 : SOLVPN, VIX
# 2017-02-23 : SOLVPN, VIX
# 2017-02-24 : SOLVPN, VIX
# 2017-02-27 : SOLVPN, VIX
# 2017-02-28 : SOLVPN, VIX
# 2017-03-01 : SOLVPN, VIX
# 2017-03-02 : SOLVPN, VIX
# 2017-03-03 : SOLVPN, VIX
# 2017-03-06 : SOLVPN, VIX
# 2017-03-07 : SOLVPN, VIX
# 2017-03-08 : SOLVPN, VIX
# 2017-03-09 : SOLVPN, VIX
# 2017-03-10 : SOLVPN, VIX
# 2017-03-13 : SOLVPN, VIX
# 2017-03-14 : SOLVPN, VIX
# 2017-03-15 : SOLVPN, VIX
# 2017-03-16 : SOLVPN, VIX
# 2017-03-17 : SOLVPN, VIX
# 2017-03-20 : SOLVPN, VIX
# 2017-03-21 : SOLVPN, VIX
# 2017-03-22 : SOLVPN, VIX
# 2017-03-23 : SOLVPN, VIX
# 2017-03-24 : SOLVPN, VIX
# 2017-03-27 : SOLVPN, VIX
# 2017-03-28 : SOLVPN, VIX
# 2017-03-29 : SOLVPN, VIX
# 2017-03-30 : SOLVPN, VIX
# 2017-03-31 : SOLVPN, VIX
# 2017-04-03 : SOLVPN, VIX
# 2017-04-04 : SOLVPN, VIX
# 2017-04-05 : SOLVPN, VIX
# 2017-04-06 : SOLVPN, VIX
# 2017-04-07 : SOLVPN, VIX
# 2017-04-10 : SOLVPN, VIX
# 2017-04-11 : SOLVPN, VIX
# 2017-04-12 : SOLVPN, VIX
# 2017-04-13 : SOLVPN, VIX
# 2017-04-17 : SOLVPN, VIX
# 2017-04-18 : SOLVPN, VIX
# 2017-04-19 : SOLVPN, VIX
# 2017-04-20 : SOLVPN, VIX
# 2017-04-21 : SOLVPN, VIX
# 2017-04-24 : SOLVPN, VIX
# 2017-04-25 : SOLVPN, VIX
# 2017-04-26 : SOLVPN, VIX
# 2017-04-27 : SOLVPN, VIX
# 2017-04-28 : SOLVPN, VIX
# 2017-05-01 : SOLVPN, VIX
# 2017-05-02 : SOLVPN, VIX
# 2017-05-03 : SOLVPN, VIX
# 2017-05-04 : SOLVPN, VIX
# 2017-05-05 : SOLVPN, VIX
# 2017-05-08 : SOLVPN, VIX
# 2017-05-09 : SOLVPN, VIX
# 2017-05-10 : SOLVPN, VIX
# 2017-05-11 : SOLVPN, VIX
# 2017-05-12 : SOLVPN, VIX
# 2017-05-15 : SOLVPN, VIX
# 2017-05-16 : SOLVPN, VIX
# 2017-05-17 : SOLVPN, VIX
# 2017-05-18 : SOLVPN, VIX
# 2017-05-19 : SOLVPN, VIX
# 2017-05-22 : SOLVPN, VIX
# 2017-05-23 : SOLVPN, VIX
# 2017-05-24 : SOLVPN, VIX
# 2017-05-25 : SOLVPN, VIX
# 2017-05-26 : SOLVPN, VIX
# 2017-05-29 : SOLVPN, COPPER, VIX
# 2017-05-30 : SOLVPN, VIX
# 2017-05-31 : SOLVPN, VIX
# 2017-06-01 : SOLVPN, VIX
# 2017-06-02 : SOLVPN, VIX
# 2017-06-05 : SOLVPN, VIX
# 2017-06-06 : SOLVPN, VIX
# 2017-06-07 : SOLVPN, VIX
# 2017-06-08 : SOLVPN, VIX
# 2017-06-09 : SOLVPN, VIX
# 2017-06-12 : SOLVPN, VIX
# 2017-06-13 : SOLVPN, VIX
# 2017-06-14 : SOLVPN, VIX
# 2017-06-15 : SOLVPN, VIX
# 2017-06-16 : SOLVPN, VIX
# 2017-06-19 : SOLVPN, VIX
# 2017-06-20 : SOLVPN, VIX
# 2017-06-21 : SOLVPN, VIX
# 2017-06-22 : SOLVPN, VIX
# 2017-06-23 : SOLVPN, VIX
# 2017-06-26 : SOLVPN, VIX
# 2017-06-27 : SOLVPN, VIX
# 2017-06-28 : SOLVPN, VIX
# 2017-06-29 : SOLVPN, VIX
# 2017-06-30 : SOLVPN, VIX
# 2017-07-03 : SOLVPN, VIX
# 2017-07-04 : SOLVPN, COPPER, VIX
# 2017-07-05 : SOLVPN, VIX
# 2017-07-06 : SOLVPN, VIX
# 2017-07-07 : SOLVPN, VIX
# 2017-07-10 : SOLVPN, VIX
# 2017-07-11 : SOLVPN, VIX
# 2017-07-12 : SOLVPN, VIX
# 2017-07-13 : SOLVPN, VIX
# 2017-07-14 : SOLVPN, VIX
# 2017-07-17 : SOLVPN, VIX
# 2017-07-18 : SOLVPN, VIX
# 2017-07-19 : SOLVPN, VIX
# 2017-07-20 : SOLVPN, VIX
# 2017-07-21 : SOLVPN, VIX
# 2017-07-24 : SOLVPN, VIX
# 2017-07-25 : SOLVPN, VIX
# 2017-07-26 : SOLVPN, VIX
# 2017-07-27 : SOLVPN, VIX
# 2017-07-28 : SOLVPN, VIX
# 2017-07-31 : SOLVPN, VIX
# 2017-08-01 : SOLVPN, VIX
# 2017-08-02 : SOLVPN, VIX
# 2017-08-03 : SOLVPN, VIX
# 2017-08-04 : SOLVPN, VIX
# 2017-08-07 : SOLVPN, VIX
# 2017-08-08 : SOLVPN, VIX
# 2017-08-09 : SOLVPN, VIX
# 2017-08-10 : SOLVPN, VIX
# 2017-08-11 : SOLVPN, VIX
# 2017-08-14 : SOLVPN, VIX
# 2017-08-15 : SOLVPN, VIX
# 2017-08-16 : SOLVPN, VIX
# 2017-08-17 : SOLVPN, VIX
# 2017-08-18 : SOLVPN, VIX
# 2017-08-21 : SOLVPN, VIX
# 2017-08-22 : SOLVPN, VIX
# 2017-08-23 : SOLVPN, VIX
# 2017-08-24 : SOLVPN, VIX
# 2017-08-25 : SOLVPN, VIX
# 2017-08-28 : SOLVPN, VIX
# 2017-08-29 : SOLVPN, VIX
# 2017-08-30 : SOLVPN, VIX
# 2017-08-31 : SOLVPN, VIX
# 2017-09-01 : SOLVPN, VIX
# 2017-09-04 : SOLVPN, COPPER, UST10Y, VIX
# 2017-09-05 : SOLVPN, VIX
# 2017-09-06 : SOLVPN, VIX
# 2017-09-07 : SOLVPN, VIX
# 2017-09-08 : SOLVPN, VIX
# 2017-09-11 : SOLVPN, VIX
# 2017-09-12 : SOLVPN, VIX
# 2017-09-13 : SOLVPN, VIX
# 2017-09-14 : SOLVPN, VIX
# 2017-09-15 : SOLVPN, VIX
# 2017-09-18 : SOLVPN, VIX
# 2017-09-19 : SOLVPN, VIX
# 2017-09-20 : SOLVPN, VIX
# 2017-09-21 : SOLVPN, VIX
# 2017-09-22 : SOLVPN, VIX
# 2017-09-25 : SOLVPN, VIX
# 2017-09-26 : SOLVPN, VIX
# 2017-09-27 : SOLVPN, VIX
# 2017-09-28 : SOLVPN, VIX
# 2017-09-29 : SOLVPN, VIX
# 2017-10-02 : SOLVPN, VIX
# 2017-10-03 : SOLVPN, VIX
# 2017-10-04 : SOLVPN, VIX
# 2017-10-05 : SOLVPN, VIX
# 2017-10-06 : SOLVPN, VIX
# 2017-10-09 : SOLVPN, VIX
# 2017-10-10 : SOLVPN, VIX
# 2017-10-11 : SOLVPN, VIX
# 2017-10-12 : SOLVPN, VIX
# 2017-10-13 : SOLVPN, VIX
# 2017-10-16 : SOLVPN, VIX
# 2017-10-17 : SOLVPN, VIX
# 2017-10-18 : SOLVPN, VIX
# 2017-10-19 : SOLVPN, VIX
# 2017-10-20 : SOLVPN, VIX
# 2017-10-23 : SOLVPN, VIX
# 2017-10-24 : SOLVPN, VIX
# 2017-10-25 : SOLVPN, VIX
# 2017-10-26 : SOLVPN, VIX
# 2017-10-27 : SOLVPN, VIX
# 2017-10-30 : SOLVPN, VIX
# 2017-10-31 : SOLVPN, VIX
# 2017-11-01 : SOLVPN, VIX
# 2017-11-02 : SOLVPN, VIX
# 2017-11-03 : SOLVPN, VIX
# 2017-11-06 : SOLVPN, VIX
# 2017-11-07 : SOLVPN, VIX
# 2017-11-08 : SOLVPN, VIX
# 2017-11-09 : SOLVPN, VIX
# 2017-11-10 : SOLVPN, VIX
# 2017-11-13 : SOLVPN, VIX
# 2017-11-14 : SOLVPN, VIX
# 2017-11-15 : SOLVPN, VIX
# 2017-11-16 : SOLVPN, VIX
# 2017-11-17 : SOLVPN, VIX
# 2017-11-20 : SOLVPN, VIX
# 2017-11-21 : SOLVPN, VIX
# 2017-11-22 : SOLVPN, VIX
# 2017-11-23 : SOLVPN, COPPER, VIX
# 2017-11-24 : SOLVPN, VIX
# 2017-11-27 : SOLVPN, VIX
# 2017-11-28 : SOLVPN, VIX
# 2017-11-29 : SOLVPN, VIX
# 2017-11-30 : SOLVPN, VIX
# 2017-12-01 : SOLVPN, VIX
# 2017-12-04 : SOLVPN, VIX
# 2017-12-05 : SOLVPN, VIX
# 2017-12-06 : SOLVPN, VIX
# 2017-12-07 : SOLVPN, VIX
# 2017-12-08 : SOLVPN, VIX
# 2017-12-11 : SOLVPN, VIX
# 2017-12-12 : SOLVPN, VIX
# 2017-12-13 : SOLVPN, VIX
# 2017-12-14 : SOLVPN, VIX
# 2017-12-15 : SOLVPN, VIX
# 2017-12-18 : SOLVPN, VIX
# 2017-12-19 : SOLVPN, VIX
# 2017-12-20 : SOLVPN, VIX
# 2017-12-21 : SOLVPN, VIX
# 2017-12-22 : SOLVPN, VIX
# 2017-12-25 : SOLVPN, COPPER, DXY, VIX
# 2017-12-26 : SOLVPN, VIX
# 2017-12-27 : SOLVPN, VIX
# 2017-12-28 : SOLVPN, VIX
# 2017-12-29 : SOLVPN, VIX
# 2018-01-01 : SOLVPN, COPPER, DXY, VIX
# 2018-01-02 : SOLVPN, VIX
# 2018-01-03 : SOLVPN, VIX
# 2018-01-04 : SOLVPN, VIX
# 2018-01-05 : SOLVPN, VIX
# 2018-01-08 : SOLVPN, VIX
# 2018-01-09 : SOLVPN, VIX
# 2018-01-10 : SOLVPN, VIX
# 2018-01-11 : SOLVPN, VIX
# 2018-01-12 : SOLVPN, VIX
# 2018-01-15 : SOLVPN, COPPER, VIX
# 2018-01-16 : SOLVPN, VIX
# 2018-01-17 : SOLVPN, VIX
# 2018-01-18 : SOLVPN, VIX
# 2018-01-19 : SOLVPN, VIX
# 2018-01-22 : SOLVPN, VIX
# 2018-01-23 : SOLVPN, VIX
# 2018-01-24 : SOLVPN, VIX
# 2018-01-25 : SOLVPN, VIX
# 2018-01-26 : SOLVPN, VIX
# 2018-01-29 : SOLVPN, VIX
# 2018-01-30 : SOLVPN, VIX
# 2018-01-31 : SOLVPN, VIX
# 2018-02-01 : SOLVPN, VIX
# 2018-02-02 : SOLVPN, VIX
# 2018-02-05 : SOLVPN, VIX
# 2018-02-06 : SOLVPN, VIX
# 2018-02-07 : SOLVPN, VIX
# 2018-02-08 : SOLVPN, VIX
# 2018-02-09 : SOLVPN, VIX
# 2018-02-12 : SOLVPN, VIX
# 2018-02-13 : SOLVPN, VIX
# 2018-02-14 : SOLVPN, VIX
# 2018-02-15 : SOLVPN, VIX
# 2018-02-16 : SOLVPN, VIX
# 2018-02-19 : SOLVPN, COPPER, VIX
# 2018-02-20 : SOLVPN, VIX
# 2018-02-21 : SOLVPN, VIX
# 2018-02-22 : SOLVPN, VIX
# 2018-02-23 : SOLVPN, VIX
# 2018-02-26 : SOLVPN, VIX
# 2018-02-27 : SOLVPN, VIX
# 2018-02-28 : SOLVPN, VIX
# 2018-03-01 : SOLVPN, VIX
# 2018-03-02 : SOLVPN, VIX
# 2018-03-05 : SOLVPN, VIX
# 2018-03-06 : SOLVPN, VIX
# 2018-03-07 : SOLVPN, VIX
# 2018-03-08 : SOLVPN, VIX
# 2018-03-09 : SOLVPN, VIX
# 2018-03-12 : SOLVPN, VIX
# 2018-03-13 : SOLVPN, VIX
# 2018-03-14 : SOLVPN, VIX
# 2018-03-15 : SOLVPN, VIX
# 2018-03-16 : SOLVPN, VIX
# 2018-03-19 : SOLVPN, VIX
# 2018-03-20 : SOLVPN, VIX
# 2018-03-21 : SOLVPN, VIX
# 2018-03-22 : SOLVPN, VIX
# 2018-03-23 : SOLVPN, VIX
# 2018-03-26 : SOLVPN, VIX
# 2018-03-27 : SOLVPN, VIX
# 2018-03-28 : SOLVPN, VIX
# 2018-03-29 : SOLVPN, VIX
# 2018-04-02 : SOLVPN, VIX
# 2018-04-03 : SOLVPN, VIX
# 2018-04-04 : SOLVPN, VIX
# 2018-04-05 : SOLVPN, VIX
# 2018-04-06 : SOLVPN, VIX
# 2018-04-09 : SOLVPN, VIX
# 2018-04-10 : SOLVPN, VIX
# 2018-04-11 : SOLVPN, VIX
# 2018-04-12 : SOLVPN, VIX
# 2018-04-13 : SOLVPN, VIX
# 2018-04-16 : SOLVPN, VIX
# 2018-04-17 : SOLVPN, VIX
# 2018-04-18 : SOLVPN, VIX
# 2018-04-19 : SOLVPN, VIX
# 2018-04-20 : SOLVPN, VIX
# 2018-04-23 : SOLVPN, VIX
# 2018-04-24 : SOLVPN, VIX
# 2018-04-25 : SOLVPN, VIX
# 2018-04-26 : SOLVPN, VIX
# 2018-04-27 : SOLVPN, VIX
# 2018-04-30 : SOLVPN, VIX
# 2018-05-01 : SOLVPN, VIX
# 2018-05-02 : SOLVPN, VIX
# 2018-05-03 : SOLVPN, VIX
# 2018-05-04 : SOLVPN, VIX
# 2018-05-07 : SOLVPN, VIX
# 2018-05-08 : SOLVPN, VIX
# 2018-05-09 : SOLVPN, VIX
# 2018-05-10 : SOLVPN, VIX
# 2018-05-11 : SOLVPN, VIX
# 2018-05-14 : SOLVPN, VIX
# 2018-05-15 : SOLVPN, VIX
# 2018-05-16 : SOLVPN, VIX
# 2018-05-17 : SOLVPN, VIX
# 2018-05-18 : SOLVPN, VIX
# 2018-05-21 : SOLVPN, VIX
# 2018-05-22 : SOLVPN, VIX
# 2018-05-23 : SOLVPN, VIX
# 2018-05-24 : SOLVPN, VIX
# 2018-05-25 : SOLVPN, VIX
# 2018-05-28 : SOLVPN, COPPER, VIX
# 2018-05-29 : SOLVPN, VIX
# 2018-05-30 : SOLVPN, VIX
# 2018-05-31 : SOLVPN, VIX
# 2018-06-01 : SOLVPN, VIX
# 2018-06-04 : SOLVPN, VIX
# 2018-06-05 : SOLVPN, VIX
# 2018-06-06 : SOLVPN, VIX
# 2018-06-07 : SOLVPN, VIX
# 2018-06-08 : SOLVPN, VIX
# 2018-06-11 : SOLVPN, VIX
# 2018-06-12 : SOLVPN, VIX
# 2018-06-13 : SOLVPN, VIX
# 2018-06-14 : SOLVPN, VIX
# 2018-06-15 : SOLVPN, VIX
# 2018-06-18 : SOLVPN, VIX
# 2018-06-19 : SOLVPN, VIX
# 2018-06-20 : SOLVPN, VIX
# 2018-06-21 : SOLVPN, VIX
# 2018-06-22 : SOLVPN, VIX
# 2018-06-25 : SOLVPN, VIX
# 2018-06-26 : SOLVPN, VIX
# 2018-06-27 : SOLVPN, VIX
# 2018-06-28 : SOLVPN, VIX
# 2018-06-29 : SOLVPN, VIX
# 2018-07-02 : SOLVPN, VIX
# 2018-07-03 : SOLVPN, VIX
# 2018-07-04 : SOLVPN, COPPER, VIX
# 2018-07-05 : SOLVPN, VIX
# 2018-07-06 : SOLVPN, VIX
# 2018-07-09 : SOLVPN, VIX
# 2018-07-10 : SOLVPN, VIX
# 2018-07-11 : SOLVPN, VIX
# 2018-07-12 : SOLVPN, VIX
# 2018-07-13 : SOLVPN, VIX
# 2018-07-16 : SOLVPN, VIX
# 2018-07-17 : SOLVPN, VIX
# 2018-07-18 : SOLVPN, VIX
# 2018-07-19 : SOLVPN, VIX
# 2018-07-20 : SOLVPN, VIX
# 2018-07-23 : SOLVPN, VIX
# 2018-07-24 : SOLVPN, VIX
# 2018-07-25 : SOLVPN, VIX
# 2018-07-26 : SOLVPN, VIX
# 2018-07-27 : SOLVPN, VIX
# 2018-07-30 : SOLVPN, VIX
# 2018-07-31 : SOLVPN, VIX
# 2018-08-01 : SOLVPN, VIX
# 2018-08-02 : SOLVPN, VIX
# 2018-08-03 : SOLVPN, VIX
# 2018-08-06 : SOLVPN, VIX
# 2018-08-07 : SOLVPN, VIX
# 2018-08-08 : SOLVPN, VIX
# 2018-08-09 : SOLVPN, VIX
# 2018-08-10 : SOLVPN, VIX
# 2018-08-13 : SOLVPN, VIX
# 2018-08-14 : SOLVPN, VIX
# 2018-08-15 : SOLVPN, VIX
# 2018-08-16 : SOLVPN, VIX
# 2018-08-17 : SOLVPN, VIX
# 2018-08-20 : SOLVPN, VIX
# 2018-08-21 : SOLVPN, VIX
# 2018-08-22 : SOLVPN, VIX
# 2018-08-23 : SOLVPN, VIX
# 2018-08-24 : SOLVPN, VIX
# 2018-08-27 : SOLVPN, VIX
# 2018-08-28 : SOLVPN, VIX
# 2018-08-29 : SOLVPN, VIX
# 2018-08-30 : SOLVPN, VIX
# 2018-08-31 : SOLVPN, VIX
# 2018-09-03 : SOLVPN, COPPER, VIX
# 2018-09-04 : SOLVPN, VIX
# 2018-09-05 : SOLVPN, VIX
# 2018-09-06 : SOLVPN, VIX
# 2018-09-07 : SOLVPN, VIX
# 2018-09-10 : SOLVPN, VIX
# 2018-09-11 : SOLVPN, VIX
# 2018-09-12 : SOLVPN, VIX
# 2018-09-13 : SOLVPN, VIX
# 2018-09-14 : SOLVPN, VIX
# 2018-09-17 : SOLVPN, VIX
# 2018-09-18 : SOLVPN, VIX
# 2018-09-19 : SOLVPN, VIX
# 2018-09-20 : SOLVPN, VIX
# 2018-09-21 : SOLVPN, VIX
# 2018-09-24 : SOLVPN, VIX
# 2018-09-25 : SOLVPN, VIX
# 2018-09-26 : SOLVPN, VIX
# 2018-09-27 : SOLVPN, VIX
# 2018-09-28 : SOLVPN, VIX
# 2018-10-01 : SOLVPN, VIX
# 2018-10-02 : SOLVPN, VIX
# 2018-10-03 : SOLVPN, VIX
# 2018-10-04 : SOLVPN, VIX
# 2018-10-05 : SOLVPN, VIX
# 2018-10-08 : SOLVPN, VIX
# 2018-10-09 : SOLVPN, VIX
# 2018-10-10 : SOLVPN, VIX
# 2018-10-11 : SOLVPN, VIX
# 2018-10-12 : SOLVPN, VIX
# 2018-10-15 : SOLVPN, VIX
# 2018-10-16 : SOLVPN, VIX
# 2018-10-17 : SOLVPN, VIX
# 2018-10-18 : SOLVPN, VIX
# 2018-10-19 : SOLVPN, VIX
# 2018-10-22 : SOLVPN, VIX
# 2018-10-23 : SOLVPN, VIX
# 2018-10-24 : SOLVPN, VIX
# 2018-10-25 : SOLVPN, VIX
# 2018-10-26 : SOLVPN, VIX
# 2018-10-29 : SOLVPN, VIX
# 2018-10-30 : SOLVPN, VIX
# 2018-10-31 : SOLVPN, VIX
# 2018-11-01 : SOLVPN, VIX
# 2018-11-02 : SOLVPN, VIX
# 2018-11-05 : SOLVPN, VIX
# 2018-11-06 : SOLVPN, VIX
# 2018-11-07 : SOLVPN, VIX
# 2018-11-08 : SOLVPN, VIX
# 2018-11-09 : SOLVPN, VIX
# 2018-11-12 : SOLVPN, VIX
# 2018-11-13 : SOLVPN, VIX
# 2018-11-14 : SOLVPN, VIX
# 2018-11-15 : SOLVPN, VIX
# 2018-11-16 : SOLVPN, VIX
# 2018-11-19 : SOLVPN, VIX
# 2018-11-20 : SOLVPN, VIX
# 2018-11-21 : SOLVPN, VIX
# 2018-11-22 : SOLVPN, VIX
# 2018-11-23 : SOLVPN, VIX
# 2018-11-26 : SOLVPN, VIX
# 2018-11-27 : SOLVPN, VIX
# 2018-11-28 : SOLVPN, VIX
# 2018-11-29 : SOLVPN, VIX
# 2018-11-30 : SOLVPN, VIX
# 2018-12-03 : SOLVPN, VIX
# 2018-12-04 : SOLVPN, VIX
# 2018-12-05 : SOLVPN, VIX
# 2018-12-06 : SOLVPN, VIX
# 2018-12-07 : SOLVPN, VIX
# 2018-12-10 : SOLVPN, VIX
# 2018-12-11 : SOLVPN, VIX
# 2018-12-12 : SOLVPN, VIX
# 2018-12-13 : SOLVPN, VIX
# 2018-12-14 : SOLVPN, VIX
# 2018-12-17 : SOLVPN, VIX
# 2018-12-18 : SOLVPN, VIX
# 2018-12-19 : SOLVPN, VIX
# 2018-12-20 : SOLVPN, VIX
# 2018-12-21 : SOLVPN, VIX
# 2018-12-24 : SOLVPN, VIX
# 2018-12-25 : SOLVPN, DXY, VIX
# 2018-12-26 : SOLVPN, VIX
# 2018-12-27 : SOLVPN, VIX
# 2018-12-28 : SOLVPN, VIX
# 2018-12-31 : SOLVPN, VIX
# 2019-01-01 : SOLVPN, DXY, VIX
# 2019-01-02 : SOLVPN, VIX
# 2019-01-03 : SOLVPN, VIX
# 2019-01-04 : SOLVPN, VIX
# 2019-01-07 : SOLVPN, VIX
# 2019-01-08 : SOLVPN, VIX
# 2019-01-09 : SOLVPN, VIX
# 2019-01-10 : SOLVPN, VIX
# 2019-01-11 : SOLVPN, VIX
# 2019-01-14 : SOLVPN, VIX
# 2019-01-15 : SOLVPN, VIX
# 2019-01-16 : SOLVPN, VIX
# 2019-01-17 : SOLVPN, VIX
# 2019-01-18 : SOLVPN, VIX
# 2019-01-21 : SOLVPN, VIX
# 2019-01-22 : SOLVPN, VIX
# 2019-01-23 : SOLVPN, VIX
# 2019-01-24 : SOLVPN, VIX
# 2019-01-25 : SOLVPN, VIX
# 2019-01-28 : SOLVPN, VIX
# 2019-01-29 : SOLVPN, VIX
# 2019-01-30 : SOLVPN, VIX
# 2019-01-31 : SOLVPN, VIX
# 2019-02-01 : SOLVPN, VIX
# 2019-02-04 : SOLVPN, VIX
# 2019-02-05 : SOLVPN, VIX
# 2019-02-06 : SOLVPN, VIX
# 2019-02-07 : SOLVPN, VIX
# 2019-02-08 : SOLVPN, VIX
# 2019-02-11 : SOLVPN, VIX
# 2019-02-12 : SOLVPN, VIX
# 2019-02-13 : SOLVPN, VIX
# 2019-02-14 : SOLVPN, VIX
# 2019-02-15 : SOLVPN, VIX
# 2019-02-18 : SOLVPN, VIX
# 2019-02-19 : SOLVPN, VIX
# 2019-02-20 : SOLVPN, VIX
# 2019-02-21 : SOLVPN, VIX
# 2019-02-22 : SOLVPN, VIX
# 2019-02-25 : SOLVPN, VIX
# 2019-02-26 : SOLVPN, VIX
# 2019-02-27 : SOLVPN, VIX
# 2019-02-28 : SOLVPN, VIX
# 2019-03-01 : SOLVPN, VIX
# 2019-03-04 : SOLVPN, VIX
# 2019-03-05 : SOLVPN, VIX
# 2019-03-06 : SOLVPN, VIX
# 2019-03-07 : SOLVPN, VIX
# 2019-03-08 : SOLVPN, VIX
# 2019-03-11 : SOLVPN, VIX
# 2019-03-12 : SOLVPN, VIX
# 2019-03-13 : SOLVPN, VIX
# 2019-03-14 : SOLVPN, VIX
# 2019-03-15 : SOLVPN, VIX
# 2019-03-18 : SOLVPN, VIX
# 2019-03-19 : SOLVPN, VIX
# 2019-03-20 : SOLVPN, VIX
# 2019-03-21 : SOLVPN, VIX
# 2019-03-22 : SOLVPN, VIX
# 2019-03-25 : SOLVPN, VIX
# 2019-03-26 : SOLVPN, VIX
# 2019-03-27 : SOLVPN, VIX
# 2019-03-28 : SOLVPN, VIX
# 2019-03-29 : SOLVPN, VIX
# 2019-04-01 : SOLVPN, VIX
# 2019-04-02 : SOLVPN, VIX
# 2019-04-03 : SOLVPN, VIX
# 2019-04-04 : SOLVPN, VIX
# 2019-04-05 : SOLVPN, VIX
# 2019-04-08 : SOLVPN, VIX
# 2019-04-09 : SOLVPN, VIX
# 2019-04-10 : SOLVPN, VIX
# 2019-04-11 : SOLVPN, VIX
# 2019-04-12 : SOLVPN, VIX
# 2019-04-15 : SOLVPN, VIX
# 2019-04-16 : SOLVPN, VIX
# 2019-04-17 : SOLVPN, VIX
# 2019-04-18 : SOLVPN, VIX
# 2019-04-19 : SOLVPN, DXY, UST10Y, VIX
# 2019-04-22 : SOLVPN, VIX
# 2019-04-23 : SOLVPN, VIX
# 2019-04-24 : SOLVPN, VIX
# 2019-04-25 : SOLVPN, VIX
# 2019-04-26 : SOLVPN, VIX
# 2019-04-29 : SOLVPN, VIX
# 2019-04-30 : SOLVPN, VIX
# 2019-05-01 : SOLVPN, VIX
# 2019-05-02 : SOLVPN, VIX
# 2019-05-03 : SOLVPN, VIX
# 2019-05-06 : SOLVPN, VIX
# 2019-05-07 : SOLVPN, VIX
# 2019-05-08 : SOLVPN, VIX
# 2019-05-09 : SOLVPN, VIX
# 2019-05-10 : SOLVPN, VIX
# 2019-05-13 : SOLVPN, VIX
# 2019-05-14 : SOLVPN, VIX
# 2019-05-15 : SOLVPN, VIX
# 2019-05-16 : SOLVPN, VIX
# 2019-05-17 : SOLVPN, VIX
# 2019-05-20 : SOLVPN, VIX
# 2019-05-21 : SOLVPN, VIX
# 2019-05-22 : SOLVPN, VIX
# 2019-05-23 : SOLVPN, VIX
# 2019-05-24 : SOLVPN, VIX
# 2019-05-27 : SOLVPN, VIX
# 2019-05-28 : SOLVPN, VIX
# 2019-05-29 : SOLVPN, VIX
# 2019-05-30 : SOLVPN, VIX
# 2019-05-31 : SOLVPN, VIX
# 2019-06-03 : SOLVPN, VIX
# 2019-06-04 : SOLVPN, VIX
# 2019-06-05 : SOLVPN, VIX
# 2019-06-06 : SOLVPN, VIX
# 2019-06-07 : SOLVPN, VIX
# 2019-06-10 : SOLVPN, VIX
# 2019-06-11 : SOLVPN, VIX
# 2019-06-12 : SOLVPN, VIX
# 2019-06-13 : SOLVPN, VIX
# 2019-06-14 : SOLVPN, VIX
# 2019-06-17 : SOLVPN, VIX
# 2019-06-18 : SOLVPN, VIX
# 2019-06-19 : SOLVPN, VIX
# 2019-06-20 : SOLVPN, VIX
# 2019-06-21 : SOLVPN, VIX
# 2019-06-24 : SOLVPN, VIX
# 2019-06-25 : SOLVPN, VIX
# 2019-06-26 : SOLVPN, VIX
# 2019-06-27 : SOLVPN, VIX
# 2019-06-28 : SOLVPN, VIX
# 2019-07-01 : SOLVPN, VIX
# 2019-07-02 : SOLVPN, VIX
# 2019-07-03 : SOLVPN, VIX
# 2019-07-04 : SOLVPN, VIX
# 2019-07-05 : SOLVPN, VIX
# 2019-07-08 : SOLVPN, VIX
# 2019-07-09 : SOLVPN, VIX
# 2019-07-10 : SOLVPN, VIX
# 2019-07-11 : SOLVPN, VIX
# 2019-07-12 : SOLVPN, VIX
# 2019-07-15 : SOLVPN, VIX
# 2019-07-16 : SOLVPN, VIX
# 2019-07-17 : SOLVPN, VIX
# 2019-07-18 : SOLVPN, VIX
# 2019-07-19 : SOLVPN, VIX
# 2019-07-22 : SOLVPN, VIX
# 2019-07-23 : SOLVPN, VIX
# 2019-07-24 : SOLVPN, VIX
# 2019-07-25 : SOLVPN, VIX
# 2019-07-26 : SOLVPN, VIX
# 2019-07-29 : SOLVPN, VIX
# 2019-07-30 : SOLVPN, VIX
# 2019-07-31 : SOLVPN, VIX
# 2019-08-01 : SOLVPN, VIX
# 2019-08-02 : SOLVPN, VIX
# 2019-08-05 : SOLVPN, VIX
# 2019-08-06 : SOLVPN, VIX
# 2019-08-07 : SOLVPN, VIX
# 2019-08-08 : SOLVPN, VIX
# 2019-08-09 : SOLVPN, VIX
# 2019-08-12 : SOLVPN, VIX
# 2019-08-13 : SOLVPN, VIX
# 2019-08-14 : SOLVPN, VIX
# 2019-08-15 : SOLVPN, VIX
# 2019-08-16 : SOLVPN, VIX
# 2019-08-19 : SOLVPN, VIX
# 2019-08-20 : SOLVPN, VIX
# 2019-08-21 : SOLVPN, VIX
# 2019-08-22 : SOLVPN, VIX
# 2019-08-23 : SOLVPN, VIX
# 2019-08-26 : SOLVPN, VIX
# 2019-08-27 : SOLVPN, VIX
# 2019-08-28 : SOLVPN, VIX
# 2019-08-29 : SOLVPN, VIX
# 2019-08-30 : SOLVPN, VIX
# 2019-09-02 : SOLVPN, VIX
# 2019-09-03 : SOLVPN, VIX
# 2019-09-04 : SOLVPN, VIX
# 2019-09-05 : SOLVPN, VIX
# 2019-09-06 : SOLVPN, VIX
# 2019-09-09 : SOLVPN, VIX
# 2019-09-10 : SOLVPN, VIX
# 2019-09-11 : SOLVPN, VIX
# 2019-09-12 : SOLVPN, VIX
# 2019-09-13 : SOLVPN, VIX
# 2019-09-16 : SOLVPN, VIX
# 2019-09-17 : SOLVPN, VIX
# 2019-09-18 : SOLVPN, VIX
# 2019-09-19 : SOLVPN, VIX
# 2019-09-20 : SOLVPN, VIX
# 2019-09-23 : SOLVPN, VIX
# 2019-09-24 : SOLVPN, VIX
# 2019-09-25 : SOLVPN, VIX
# 2019-09-26 : SOLVPN, VIX
# 2019-09-27 : SOLVPN, VIX
# 2019-09-30 : SOLVPN, VIX
# 2019-10-01 : SOLVPN, VIX
# 2019-10-02 : SOLVPN, VIX
# 2019-10-03 : SOLVPN, VIX
# 2019-10-04 : SOLVPN, VIX
# 2019-10-07 : SOLVPN, VIX
# 2019-10-08 : SOLVPN, VIX
# 2019-10-09 : SOLVPN, VIX
# 2019-10-10 : SOLVPN, VIX
# 2019-10-11 : SOLVPN, VIX
# 2019-10-14 : SOLVPN, VIX
# 2019-10-15 : SOLVPN, VIX
# 2019-10-16 : SOLVPN, VIX
# 2019-10-17 : SOLVPN, VIX
# 2019-10-18 : SOLVPN, VIX
# 2019-10-21 : SOLVPN, VIX
# 2019-10-22 : SOLVPN, VIX
# 2019-10-23 : SOLVPN, VIX
# 2019-10-24 : SOLVPN, VIX
# 2019-10-25 : SOLVPN, VIX
# 2019-10-28 : SOLVPN, VIX
# 2019-10-29 : SOLVPN, VIX
# 2019-10-30 : SOLVPN, VIX
# 2019-10-31 : SOLVPN, VIX
# 2019-11-01 : SOLVPN, VIX
# 2019-11-04 : SOLVPN, VIX
# 2019-11-05 : SOLVPN, VIX
# 2019-11-06 : SOLVPN, VIX
# 2019-11-07 : SOLVPN, VIX
# 2019-11-08 : SOLVPN, VIX
# 2019-11-11 : SOLVPN, VIX
# 2019-11-12 : SOLVPN, VIX
# 2019-11-13 : SOLVPN, VIX
# 2019-11-14 : SOLVPN, VIX
# 2019-11-15 : SOLVPN, VIX
# 2019-11-18 : SOLVPN, VIX
# 2019-11-19 : SOLVPN, VIX
# 2019-11-20 : SOLVPN, VIX
# 2019-11-21 : SOLVPN, VIX
# 2019-11-22 : SOLVPN, VIX
# 2019-11-25 : SOLVPN, VIX
# 2019-11-26 : SOLVPN, VIX
# 2019-11-27 : SOLVPN, VIX
# 2019-11-28 : SOLVPN, VIX
# 2019-11-29 : SOLVPN, VIX
# 2019-12-02 : SOLVPN, VIX
# 2019-12-03 : SOLVPN, VIX
# 2019-12-04 : SOLVPN, VIX
# 2019-12-05 : SOLVPN, VIX
# 2019-12-06 : SOLVPN, VIX
# 2019-12-09 : SOLVPN, VIX
# 2019-12-10 : SOLVPN, VIX
# 2019-12-11 : SOLVPN, VIX
# 2019-12-12 : SOLVPN, VIX
# 2019-12-13 : SOLVPN, VIX
# 2019-12-16 : SOLVPN, VIX
# 2019-12-17 : SOLVPN, VIX
# 2019-12-18 : SOLVPN, VIX
# 2019-12-19 : SOLVPN, VIX
# 2019-12-20 : SOLVPN, VIX
# 2019-12-23 : SOLVPN, VIX
# 2019-12-24 : SOLVPN, VIX
# 2019-12-25 : SOLVPN, DXY, VIX
# 2019-12-26 : SOLVPN, VIX
# 2019-12-27 : SOLVPN, VIX
# 2019-12-30 : SOLVPN, VIX
# 2019-12-31 : SOLVPN, VIX
# 2020-01-01 : SOLVPN, DXY, VIX
# 2020-01-02 : SOLVPN
# 2020-01-03 : SOLVPN
# 2020-01-06 : SOLVPN
# 2020-01-07 : SOLVPN
# 2020-01-08 : SOLVPN
# 2020-01-09 : SOLVPN
# 2020-01-10 : SOLVPN
# 2020-01-13 : SOLVPN
# 2020-01-14 : SOLVPN
# 2020-01-15 : SOLVPN
# 2020-01-16 : SOLVPN
# 2020-01-17 : SOLVPN
# 2020-01-20 : SOLVPN, VIX
# 2020-01-21 : SOLVPN
# 2020-01-22 : SOLVPN
# 2020-01-23 : SOLVPN
# 2020-01-24 : SOLVPN
# 2020-01-27 : SOLVPN
# 2020-01-28 : SOLVPN
# 2020-01-29 : SOLVPN
# 2020-01-30 : SOLVPN
# 2020-01-31 : SOLVPN
# 2020-02-03 : SOLVPN
# 2020-02-04 : SOLVPN
# 2020-02-05 : SOLVPN
# 2020-02-06 : SOLVPN
# 2020-02-07 : SOLVPN
# 2020-02-10 : SOLVPN
# 2020-02-11 : SOLVPN
# 2020-02-12 : SOLVPN
# 2020-02-13 : SOLVPN
# 2020-02-14 : SOLVPN
# 2020-02-17 : SOLVPN, VIX
# 2020-02-18 : SOLVPN
# 2020-02-19 : SOLVPN
# 2020-02-20 : SOLVPN
# 2020-02-21 : SOLVPN
# 2020-02-24 : SOLVPN
# 2020-02-25 : SOLVPN
# 2020-02-26 : SOLVPN
# 2020-02-27 : SOLVPN
# 2020-02-28 : SOLVPN
# 2020-03-02 : SOLVPN
# 2020-03-03 : SOLVPN
# 2020-03-04 : SOLVPN
# 2020-03-05 : SOLVPN
# 2020-03-06 : SOLVPN
# 2020-03-09 : SOLVPN
# 2020-03-10 : SOLVPN
# 2020-03-11 : SOLVPN
# 2020-03-12 : SOLVPN
# 2020-03-13 : SOLVPN
# 2020-03-16 : SOLVPN
# 2020-03-17 : SOLVPN
# 2020-03-18 : SOLVPN
# 2020-03-19 : SOLVPN
# 2020-03-20 : SOLVPN
# 2020-03-23 : SOLVPN
# 2020-03-24 : SOLVPN
# 2020-03-25 : SOLVPN
# 2020-03-26 : SOLVPN
# 2020-03-27 : SOLVPN
# 2020-03-30 : SOLVPN
# 2020-03-31 : SOLVPN
# 2020-04-01 : SOLVPN
# 2020-04-02 : SOLVPN
# 2020-04-03 : SOLVPN
# 2020-04-06 : SOLVPN
# 2020-04-07 : SOLVPN
# 2020-04-08 : SOLVPN
# 2020-04-09 : SOLVPN
# 2020-04-10 : SOLVPN, DXY, UST10Y, VIX
# 2020-04-13 : SOLVPN
# 2020-04-14 : SOLVPN
# 2020-04-15 : SOLVPN
# 2020-04-16 : SOLVPN
# 2020-04-17 : SOLVPN
# 2020-04-20 : SOLVPN
# 2020-04-21 : SOLVPN
# 2020-04-22 : SOLVPN
# 2020-04-23 : SOLVPN
# 2020-04-24 : SOLVPN
# 2020-04-27 : SOLVPN
# 2020-04-28 : SOLVPN
# 2020-04-29 : SOLVPN
# 2020-04-30 : SOLVPN
# 2020-05-01 : SOLVPN
# 2020-05-04 : SOLVPN
# 2020-05-05 : SOLVPN
# 2020-05-06 : SOLVPN
# 2020-05-07 : SOLVPN
# 2020-05-08 : SOLVPN
# 2020-05-11 : SOLVPN
# 2020-05-12 : SOLVPN
# 2020-05-13 : SOLVPN
# 2020-05-14 : SOLVPN
# 2020-05-15 : SOLVPN
# 2020-05-18 : SOLVPN
# 2020-05-19 : SOLVPN
# 2020-05-20 : SOLVPN
# 2020-05-21 : SOLVPN
# 2020-05-22 : SOLVPN
# 2020-05-25 : SOLVPN, VIX
# 2020-05-26 : SOLVPN
# 2020-05-27 : SOLVPN
# 2020-05-28 : SOLVPN
# 2020-05-29 : SOLVPN
# 2020-06-01 : SOLVPN
# 2020-06-02 : SOLVPN
# 2020-06-03 : SOLVPN
# 2020-06-04 : SOLVPN
# 2020-06-05 : SOLVPN
# 2020-06-08 : SOLVPN
# 2020-06-09 : SOLVPN
# 2020-06-10 : SOLVPN
# 2020-06-11 : SOLVPN
# 2020-06-12 : SOLVPN
# 2020-06-15 : SOLVPN
# 2020-06-16 : SOLVPN
# 2020-06-17 : SOLVPN
# 2020-06-18 : SOLVPN
# 2020-06-19 : SOLVPN
# 2020-06-22 : SOLVPN
# 2020-06-23 : SOLVPN
# 2020-06-24 : SOLVPN
# 2020-06-25 : SOLVPN
# 2020-06-26 : SOLVPN
# 2020-06-29 : SOLVPN
# 2020-06-30 : SOLVPN
# 2020-07-01 : SOLVPN
# 2020-07-02 : SOLVPN
# 2020-07-03 : SOLVPN, UST10Y
# 2020-07-06 : SOLVPN
# 2020-07-07 : SOLVPN
# 2020-07-08 : SOLVPN
# 2020-07-09 : SOLVPN
# 2020-07-10 : SOLVPN
# 2020-07-13 : SOLVPN
# 2020-07-14 : SOLVPN
# 2020-07-15 : SOLVPN
# 2020-07-16 : SOLVPN
# 2020-07-17 : SOLVPN
# 2020-07-20 : SOLVPN
# 2020-07-21 : SOLVPN
# 2020-07-22 : SOLVPN
# 2020-07-23 : SOLVPN
# 2020-07-24 : SOLVPN
# 2020-07-27 : SOLVPN
# 2020-07-28 : SOLVPN
# 2020-07-29 : SOLVPN
# 2020-07-30 : SOLVPN
# 2020-07-31 : SOLVPN
# 2020-08-03 : SOLVPN
# 2020-08-04 : SOLVPN
# 2020-08-05 : SOLVPN
# 2020-08-06 : SOLVPN
# 2020-08-07 : SOLVPN
# 2020-08-10 : SOLVPN
# 2020-08-11 : SOLVPN
# 2020-08-12 : SOLVPN
# 2020-08-13 : SOLVPN
# 2020-08-14 : SOLVPN
# 2020-08-17 : SOLVPN
# 2020-08-18 : SOLVPN
# 2020-08-19 : SOLVPN
# 2020-08-20 : SOLVPN
# 2020-08-21 : SOLVPN
# 2020-08-24 : SOLVPN
# 2020-08-25 : SOLVPN
# 2020-08-26 : SOLVPN
# 2020-08-27 : SOLVPN
# 2020-08-28 : SOLVPN
# 2020-08-31 : SOLVPN
# 2020-09-01 : SOLVPN
# 2020-09-02 : SOLVPN
# 2020-09-03 : SOLVPN
# 2020-09-04 : SOLVPN
# 2020-09-07 : SOLVPN, VIX
# 2020-09-08 : SOLVPN
# 2020-09-09 : SOLVPN
# 2020-09-10 : SOLVPN
# 2020-09-11 : SOLVPN
# 2020-09-14 : SOLVPN
# 2020-09-15 : SOLVPN
# 2020-09-16 : SOLVPN
# 2020-09-17 : SOLVPN
# 2020-09-18 : SOLVPN
# 2020-09-21 : SOLVPN
# 2020-09-22 : SOLVPN
# 2020-09-23 : SOLVPN
# 2020-09-24 : SOLVPN
# 2020-09-25 : SOLVPN
# 2020-09-28 : SOLVPN
# 2020-09-29 : SOLVPN
# 2020-09-30 : SOLVPN
# 2020-10-01 : SOLVPN
# 2020-10-02 : SOLVPN
# 2020-10-05 : SOLVPN
# 2020-10-06 : SOLVPN
# 2020-10-07 : SOLVPN
# 2020-10-08 : SOLVPN
# 2020-10-09 : SOLVPN
# 2020-12-25 : COPPER, DXY, UST10Y
# 2021-01-01 : DXY, UST10Y, VIX
# 2021-01-18 : VIX
# 2021-02-15 : VIX
# 2021-04-02 : COPPER
# 2021-05-31 : VIX
# 2021-07-05 : VIX
# 2021-09-06 : VIX
# 2021-12-24 : DXY, UST10Y
# 2022-01-17 : VIX
# 2022-02-21 : VIX
# 2022-04-15 : DXY, UST10Y
# 2022-11-11 : UST10Y
# 2022-12-26 : DXY
# 2023-01-02 : DXY, VIX
# 2023-04-07 : COPPER
# 2023-06-19 : SOLVPN
# 2023-07-04 : SOLVPN
# 2023-09-04 : SOLVPN
# 2023-11-23 : SOLVPN
# 2023-12-25 : SOLVPN, DXY
# 2024-01-01 : SOLVPN, DXY, VIX
# 2024-01-15 : SOLVPN
# 2024-02-19 : SOLVPN
# 2024-03-29 : SOLVPN, DXY
# 2024-05-27 : SOLVPN
# 2024-06-19 : SOLVPN
# 2024-07-04 : SOLVPN
# 2024-09-02 : SOLVPN
# 2024-10-14 : UST10Y
# 2024-11-11 : UST10Y
# 2024-11-28 : SOLVPN, COPPER, UST10Y
# 2025-01-09 : SOLVPN
# 2025-01-20 : SOLVPN, COPPER, UST10Y
# 2025-02-17 : SOLVPN, COPPER, UST10Y
# 2025-05-26 : SOLVPN
# 2025-06-19 : SOLVPN
# 2025-07-04 : SOLVPN
# 2025-09-01 : SOLVPN
# 2025-11-27 : SOLVPN
# 2025-12-25 : SOLVPN, DXY, VIX
# 2026-01-01 : SOLVPN, DXY
# 2026-01-13 : SOLVPN
# 2026-01-14 : SOLVPN
# 2026-01-15 : SOLVPN
# 2026-01-16 : SOLVPN
# 2026-01-19 : SOLVPN, VIX
#
# Saved: ./missing_weekday_causes.csv
