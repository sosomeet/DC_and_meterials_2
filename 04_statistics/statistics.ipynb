# %%
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.stats import skew, kurtosis

# ============================================================
# Descriptive Statistics (논문 Table 1 대응)
# ============================================================

# -----------------------------
# Config
# -----------------------------
BASE_DIR = Path("./")

INPUT_FILE = BASE_DIR / "tvpvar_input_scaled.csv"
OUTPUT_FILE = BASE_DIR / "descriptive_stats.csv"

DATE_CANDIDATES = ["Date", "date", "DATE"]

# -----------------------------
# Load
# -----------------------------
df = pd.read_csv(INPUT_FILE)

# 날짜 컬럼 제거
date_col = None
for c in DATE_CANDIDATES:
    if c in df.columns:
        date_col = c
        break

if date_col:
    df = df.drop(columns=[date_col])

# numeric 컬럼만 사용
df = df.select_dtypes(include=[np.number])

print("Using columns:", list(df.columns))

# -----------------------------
# Descriptive Statistics
# -----------------------------
rows = []

for col in df.columns:
    s = df[col].dropna()

    row = {
        "variable": col,
        "mean": s.mean(),
        "std": s.std(),
        "min": s.min(),
        "max": s.max(),
        "skewness": skew(s),
        "kurtosis": kurtosis(s, fisher=True),  # excess kurtosis
        "n_obs": len(s)
    }

    rows.append(row)

result = pd.DataFrame(rows)

# -----------------------------
# 정렬 (논문 스타일)
# -----------------------------
result = result[
    ["variable", "mean", "std", "min", "max", "skewness", "kurtosis", "n_obs"]
]

# -----------------------------
# 저장
# -----------------------------
result.to_csv(OUTPUT_FILE, index=False, encoding="utf-8-sig")

print("\nSaved:", OUTPUT_FILE)
print("\nPreview:")
print(result.to_string(index=False))
# Out:
# Using columns: ['dlog_SOLVPN', 'dlog_COPPER', 'dlog_GOLD', 'dlog_SILVER', 'dlog_DXY', 'd_UST10Y', 'd_VIX']
#
# Saved: descriptive_stats.csv
#
# Preview:
#    variable          mean      std        min      max  skewness  kurtosis  n_obs
# dlog_SOLVPN  6.858521e-18 1.000483  -4.023294 5.671648  0.005074  1.670855   1036
# dlog_COPPER -1.714630e-17 1.000483 -14.427255 7.114386 -2.640176 43.609910   1036
#   dlog_GOLD -2.057556e-17 1.000483  -5.404465 3.859781 -0.358778  2.621274   1036
# dlog_SILVER  1.028778e-17 1.000483  -4.882101 5.628866  0.112920  3.343708   1036
#    dlog_DXY -3.086334e-17 1.000483  -4.833299 3.549124 -0.277280  1.348628   1036
#    d_UST10Y  2.229019e-17 1.000483  -4.731293 3.899813 -0.101125  1.064459   1036
#       d_VIX  1.993258e-17 1.000483 -10.280154 8.303570  0.363599 22.456472   1036
