# %%
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.stats import skew, kurtosis

# ============================================================
# Descriptive Statistics (논문 Table 1 대응)
# ============================================================

# -----------------------------
# Config
# -----------------------------
BASE_DIR = Path("./")

INPUT_FILE = BASE_DIR / "tvpvar_input_scaled.csv"
OUTPUT_FILE = BASE_DIR / "descriptive_stats.csv"

DATE_CANDIDATES = ["Date", "date", "DATE"]

# -----------------------------
# Load
# -----------------------------
df = pd.read_csv(INPUT_FILE)

# 날짜 컬럼 제거
date_col = None
for c in DATE_CANDIDATES:
    if c in df.columns:
        date_col = c
        break

if date_col:
    df = df.drop(columns=[date_col])

# numeric 컬럼만 사용
df = df.select_dtypes(include=[np.number])

print("Using columns:", list(df.columns))

# -----------------------------
# Descriptive Statistics
# -----------------------------
rows = []

for col in df.columns:
    s = df[col].dropna()

    row = {
        "variable": col,
        "mean": s.mean(),
        "std": s.std(),
        "min": s.min(),
        "max": s.max(),
        "skewness": skew(s),
        "kurtosis": kurtosis(s, fisher=True),  # excess kurtosis
        "n_obs": len(s)
    }

    rows.append(row)

result = pd.DataFrame(rows)

# -----------------------------
# 정렬 (논문 스타일)
# -----------------------------
result = result[
    ["variable", "mean", "std", "min", "max", "skewness", "kurtosis", "n_obs"]
]

# -----------------------------
# 저장
# -----------------------------
result.to_csv(OUTPUT_FILE, index=False, encoding="utf-8-sig")

print("\nSaved:", OUTPUT_FILE)
print("\nPreview:")
print(result.to_string(index=False))
# Out:
# Using columns: ['dlog_SOLVPN', 'dlog_COPPER', 'dlog_GOLD', 'dlog_SILVER', 'dlog_DXY', 'dlog_OIL', 'dlog_GAS', 'd_UST10Y', 'd_VIX']
#
# Saved: descriptive_stats.csv
#
# Preview:
#    variable          mean      std        min      max  skewness  kurtosis  n_obs
# dlog_SOLVPN -3.442552e-18 1.000485  -4.024207 5.671041  0.006446  1.681808   1032
# dlog_COPPER  1.721276e-17 1.000485 -14.459334 7.135127 -2.683281 44.149600   1032
#   dlog_GOLD  2.065531e-17 1.000485  -5.446596 3.893745 -0.392657  2.634500   1032
# dlog_SILVER  1.204893e-17 1.000485  -4.924530 5.687975  0.097226  3.460585   1032
#    dlog_DXY  2.409786e-17 1.000485  -4.825502 3.545327 -0.274543  1.339623   1032
#    dlog_OIL -1.893404e-17 1.000485  -5.499376 3.549713 -0.552047  2.162466   1032
#    dlog_GAS  1.721276e-18 1.000485 -14.439044 7.618301 -3.725201 64.239911   1032
#    d_UST10Y  6.885104e-18 1.000485  -4.733718 3.898929 -0.103000  1.075686   1032
#       d_VIX -1.936436e-18 1.000485 -10.273751 8.296710  0.364270 22.476368   1032
